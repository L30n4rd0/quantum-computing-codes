# %% [markdown]
# ## Gráficos de simulações realizadas com QisKit no simulador ibmq_qasm_simulator

# %% [markdown]
# ## imports

# %%
from qiskit.tools.visualization import plot_histogram

# %% [markdown]
# ### Quatro simulações do algoritmo de busca realizadas no simulador online ibmq_qasm_simulator
# - Job id: 5ce0ad0a3c65ac0076f93db0
# - Job id: 5ce0ad103ca9a10070c72c6d
# - Job id: 5ce0ad13c692ab00768339d4
# - Job id: 5ce0ad16c692ab00768339d6

# %%
python_module = "qiskit_cqd_search_data_base_backend"
algorithm = "Algoritmo de busca em base desordenada"
shots = 1024
work_qubits = 2
auxiliaries_qubits = 1
backend_name = "ibmq_qasm_simulator"
backend_type = "Simulador online"
marked_states = "11"

# %%
executions_counts = [
    {'011': 245, '110': 264, '001': 252, '101': 263},
    {'110': 252, '001': 259, '101': 254, '011': 259},
    {'011': 244, '001': 257, '101': 273, '110': 250},
    {'110': 252, '101': 247, '011': 245, '001': 280}
]

# %%
# Plot results with legend

legend = []

for index in range(len(executions_counts)):
    legend.append("Execução: " + str(index + 1))

# %%
# Plot graph
plot_histogram(
    data = executions_counts, 
    figsize = (15,5), 
    color = None, 
    number_to_keep = None, 
    sort = 'asc', 
    legend = legend, 
    bar_labels = False, 
    title = "HISTOGRAMA: " + algorithm + ", " + str(shots) + " shots, " + 
            str(work_qubits) + " qubits de trabalho e " + str(auxiliaries_qubits) + " qubit auxiliar" + 
            "\nEXECUTADO EM: " + backend_type + " " + backend_name + 
            "\nESTADOS MARCADOS: " + marked_states
)
