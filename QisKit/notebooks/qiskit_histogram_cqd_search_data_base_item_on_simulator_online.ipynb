# %% [markdown]
# ## Gráficos de simulações realizadas com QisKit no simulador online

# %% [markdown]
# ## imports

# %%
from qiskit.tools.visualization import plot_histogram

# %% [markdown]
# ### Quatro simulações do algoritmo de busca realizadas no simulador online ibmq_qasm_simulator com as seguintes configurações
# - python module: qiskit_cqd_search_data_base_backend
# - shots: 1024
# - work qubits: 2
# - auxiliaries qubits: 1
# - marked states: 11
# - backend_name: ibmq_qasm_simulator
# - Job id: 5ce0ad0a3c65ac0076f93db0
# - Job id: 5ce0ad103ca9a10070c72c6d
# - Job id: 5ce0ad13c692ab00768339d4
# - Job id: 5ce0ad16c692ab00768339d6

# %%
executions_counts = [
    {'011': 245, '110': 264, '001': 252, '101': 263},
    {'110': 252, '001': 259, '101': 254, '011': 259},
    {'011': 244, '001': 257, '101': 273, '110': 250},
    {'110': 252, '101': 247, '011': 245, '001': 280}
]

# %%
# Plot results with legend

legend = []

for index in range(len(executions_counts)):
    legend.append("Execução: " + str(index + 1))

# %%
# Plot graph
plot_histogram(
    executions_counts, 
    legend=legend, 
    figsize=(15,5), 
    bar_labels=False
)
