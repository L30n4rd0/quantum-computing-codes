# %% [markdown]
# ## Gráficos de comparando simulações realizadas com QisKit em diferentes backends

# %% [markdown]
# ## imports

# %%
from qiskit.tools.visualization import plot_histogram

# %% [markdown]
# ### Comparando simulações do algoritmo n_4_fixed_point_search_data_base_item  realizadas com QisKit em diferentes backends
# - Job id: não se aplica --> qasm_simulator
# - Job id: 5ce756c37952f80077a44547 --> ibmq_qasm_simulator
# - Job id: 5ce755a3a2e59e00708cb6a4 --> ibmqx4
# - Job id: 5ce75a29a95119007977e604 --> ibmqx2

# %%
python_module = "qiskit_cqd_n_4_fixed_point_search_data_base_backend"
algorithm = "Algoritmo de busca em base desordenada"
shots = 8 * 1024
work_qubits = 4
auxiliaries_qubits = 1
backend_name = "vários"
backend_type = "Dispositivo real"
marked_states = "0011, 0111, 1011, 1111"

# %%
executions_counts = [
#     {'11010': 19, '01100': 19, '10101': 33, '11011': 31, '00110': 65, '11000': 23, '11001': 44, '01000': 23, '00000': 23, '10110': 65, '10011': 47, '01001': 39, '11100': 30, '11101': 34, '01110': 62, '10010': 21, '01101': 52, '00101': 50, '11110': 66, '10000': 26, '00011': 40, '01010': 27, '00001': 36, '00100': 9, '00010': 24, '10001': 51, '10100': 20, '01011': 45},
    {'10100': 199, '10011': 323, '10101': 327, '10000': 165, '00110': 534, '01001': 320, '00001': 323, '01101': 314, '11110': 501, '00010': 190, '11101': 337, '10110': 484, '00101': 356, '01011': 305, '11010': 191, '11011': 306, '11001': 332, '00100': 193, '10001': 332, '01010': 220, '11100': 183, '01100': 169, '00000': 193, '11000': 193, '01110': 498, '01000': 192, '00011': 333, '10010': 179},
    {'11101': 305, '00111': 64, '10101': 282, '00110': 378, '01100': 320, '10111': 53, '01001': 315, '10110': 379, '00000': 357, '10100': 307, '10010': 173, '11110': 370, '00101': 297, '00010': 143, '11010': 196, '00011': 174, '10001': 345, '11011': 179, '10011': 142, '11100': 312, '01110': 350, '10000': 358, '11001': 335, '01000': 349, '00100': 309, '11111': 64, '11000': 350, '01111': 51, '01010': 154, '01101': 286, '01011': 155, '00001': 340},
    {'00010': 167, '10111': 164, '01001': 609, '10101': 291, '01000': 145, '11010': 112, '01110': 149, '10010': 159, '01101': 251, '01011': 395, '00001': 675, '10001': 690, '00101': 303, '00111': 176, '00011': 433, '11110': 130, '11101': 296, '11100': 89, '01111': 142, '11111': 143, '01010': 114, '11001': 621, '11011': 422, '00100': 117, '10100': 124, '11000': 161, '00110': 137, '10000': 141, '10110': 146, '01100': 91, '00000': 152, '10011': 447}
]

# %%
# Plot results with legend

legend = []
# legend.append("qasm_simulator")
legend.append("ibmq_qasm_simulator")
legend.append("ibmqx4")
legend.append("ibmqx2")

# for index in range(len(executions_counts)):
#     legend.append("Execução: " + str(index + 1))

# %%
# Plot graph
plot_histogram(
    data = executions_counts, 
    figsize = (15,5), 
    color = None, 
    number_to_keep = None, 
    sort = 'asc', 
    legend = legend, 
    bar_labels = False, 
    title = "HISTOGRAMA: " + algorithm + ", " + str(shots) + " shots, " + 
            str(work_qubits) + " qubits de trabalho e " + str(auxiliaries_qubits) + " qubit auxiliar" + 
            "\nEXECUTADO EM: " + backend_type + " " + backend_name + 
            "\nESTADOS MARCADOS: " + marked_states
)

# %% [markdown]
# ### Comparando simulações do algoritmo n_4_fixed_point_search_data_base_item  realizadas com QisKit em diferentes backends
# - Job id: não se aplica --> qasm_simulator
# - Job id: 5ce83aa5766e940076c876e9 --> ibmq_qasm_simulator
# - Job id: 5ce81f3d4aa56a0072184800 --> ibmqx4
# - Job id: 5ce82c686a86a1007d9654b4 --> ibmqx2

# %%
python_module = "qiskit_cqd_n_4_fixed_point_search_data_base_backend"
algorithm = "Algoritmo de busca em base desordenada"
shots = 8 * 1024
work_qubits = 3
auxiliaries_qubits = 1
backend_name = "vários"
backend_type = "Dispositivo real"
marked_states = "011, 111"

# %%
executions_counts = [
#     {'0001': 97, '0110': 126, '1010': 16, '0100': 17, '0101': 133, '0010': 18, '1000': 16, '1110': 124, '1100': 13, '1101': 114, '0011': 107, '1011': 120, '0000': 13, '1001': 110},
    {'1011': 902, '1101': 882, '0001': 876, '0101': 896, '1001': 933, '1100': 105, '0100': 111, '1000': 119, '0110': 1039, '1010': 108, '0011': 971, '0010': 95, '0000': 117, '1110': 1038},
    {'0101': 837, '0110': 676, '0010': 199, '0011': 475, '0111': 148, '0100': 437, '1100': 380, '1000': 462, '1111': 153, '1010': 203, '0000': 476, '1001': 870, '1011': 427, '1110': 721, '0001': 960, '1101': 768},
    {'0100': 240, '0111': 349, '1111': 312, '1110': 274, '1000': 264, '1001': 1314, '0001': 1287, '0010': 237, '1100': 242, '1011': 859, '0110': 294, '1101': 508, '0000': 299, '0011': 905, '1010': 231, '0101': 577}
]

# %%
# Plot results with legend

legend = []
# legend.append("qasm_simulator")
legend.append("ibmq_qasm_simulator")
legend.append("ibmqx4")
legend.append("ibmqx2")

# for index in range(len(executions_counts)):
#     legend.append("Execução: " + str(index + 1))

# %%
# Plot graph
plot_histogram(
    data = executions_counts, 
    figsize = (15,5), 
    color = None, 
    number_to_keep = None, 
    sort = 'asc', 
    legend = legend, 
    bar_labels = False, 
    title = "HISTOGRAMA: " + algorithm + ", " + str(shots) + " shots, " + 
            str(work_qubits) + " qubits de trabalho e " + str(auxiliaries_qubits) + " qubit auxiliar" + 
            "\nEXECUTADO EM: " + backend_type + " " + backend_name + 
            "\nESTADOS MARCADOS: " + marked_states
)
