# %% [markdown]
# ## Gráficos de simulações realizadas com QisKit no IBMQ

# %% [markdown]
# ## imports

# %%
from qiskit.tools.visualization import plot_histogram

# %% [markdown]
# ### Quatro simulações do algoritmo de busca realizadas com as seguintes configurações
# - módulo python: qiskit_cqd_search_data_base_ibmq
# - shots: 1024
# - Job id: 5cb63d7bcde125005948bd25
# - Job id: 5cb63da467a45d0079899984
# - Job id: 5cb775ed67a45d0079899ce9
# - Job id: 5cb776c5bece3b00791722c3
# - backend_name: ibmqx4

# %%
executions_counts = [
    {'101': 190, '010': 71, '001': 162, '110': 173, '100': 129, '111': 75, '000': 142, '011': 82},
    {'101': 205, '010': 51, '001': 181, '110': 155, '100': 133, '111': 61, '000': 149, '011': 89},
    {'101': 232, '010': 27, '001': 244, '110': 197, '100': 103, '111': 46, '000': 76, '011': 99},
    {'101': 224, '010': 44, '001': 206, '110': 177, '100': 110, '111': 41, '000': 87, '011': 135}
]

# %%
# Plot results with legend

legend = []

for index in range(len(executions_counts)):
    legend.append("Execução: " + str(index + 1))

# %%
# Plot graph
plot_histogram(
    executions_counts, 
    legend=legend, 
    figsize=(15,5), 
    bar_labels=False
)

# %% [markdown]
# ### Duas simulações do algoritmo de busca realizadas com as seguintes configurações
# - módulo python: qiskit_cqd_search_data_base_ibmq
# - shots: 2 * 1024
# - Job id: 5cb646fbffc8ac0067e175d4
# - Job id: 5cb6473dbdbb490059c1116f
# - Job id: 5cb77b70e80ab8005d957b1f
# - Job id: 5cb77c6f122807005bfd0999
# - backend_name: ibmqx4

# %%
executions_counts = [
    {'101': 417, '010': 82, '001': 387, '110': 347, '100': 237, '111': 142, '000': 231, '011': 205},
    {'101': 440, '010': 84, '001': 360, '110': 310, '100': 248, '111': 134, '000': 243, '011': 229},
    {'101': 467, '010': 67, '001': 469, '110': 350, '100': 204, '111': 98, '000': 158, '011': 235},
    {'101': 507, '010': 66, '001': 431, '110': 362, '100': 198, '111': 101, '000': 142, '011': 241}
]

# %%
# Plot results with legend

legend = []

for index in range(len(executions_counts)):
    legend.append("Execução: " + str(index + 1))

# %%
# Plot graph
plot_histogram(
    executions_counts, 
    legend=legend, 
    figsize=(15,5), 
    bar_labels=False
)

# %%
print("....")
# Out:
# ....
