    {'11011': 28, '11001': 30, '10001': 36, '00110': 49, '00000': 41, '11111': 12, '11110': 61, '11000': 38, '10100': 18, '01101': 37, '01000': 42, '00111': 14, '10111': 12, '01001': 36, '11100': 48, '11010': 26, '10110': 53, '01100': 41, '10011': 28, '10000': 30, '01011': 26, '01110': 42, '00011': 23, '01010': 19, '00101': 33, '00100': 41, '00001': 43, '00010': 15, '10010': 23, '01111': 9, '10101': 33, '11101': 37},
    {'00010': 15, '10010': 26, '00101': 35, '00110': 54, '10111': 14, '00100': 35, '00001': 33, '01000': 40, '10101': 34, '10110': 50, '01101': 45, '11100': 27, '11001': 34, '10100': 34, '10000': 42, '11000': 39, '11111': 15, '10011': 24, '01010': 26, '00000': 41, '11011': 23, '01001': 39, '11110': 42, '01100': 47, '01110': 51, '11101': 30, '00111': 12, '01111': 12, '01011': 27, '00011': 26, '11010': 21, '10001': 31},
    {'00001': 31, '11001': 34, '01010': 28, '00010': 24, '01100': 36, '11110': 53, '11111': 14, '00110': 63, '10000': 40, '00111': 3, '11011': 24, '10011': 23, '00011': 26, '00101': 38, '11100': 42, '01101': 37, '10101': 34, '01110': 46, '10111': 4, '11101': 32, '01111': 11, '11000': 32, '01011': 23, '01000': 38, '00100': 41, '00000': 38, '01001': 29, '10010': 21, '10110': 68, '11010': 17, '10001': 50, '10100': 24}
]

# %%
# Plot results with legend

legend = []

for index in range(len(executions_counts)):
    legend.append("Execução: " + str(index + 1))

# %%
# Plot graph
plot_histogram(
    data = executions_counts, 
    figsize = (15,5), 
    color = None, 
    number_to_keep = None, 
    sort = 'asc', 
    legend = legend, 
    bar_labels = False, 
    title = "HISTOGRAMA: " + algorithm + ", " + str(shots) + " shots, " + 
            str(work_qubits) + " qubits de trabalho e " + str(auxiliaries_qubits) + " qubit auxiliar" + 
            "\nEXECUTADO EM: " + backend_type + " " + backend_name + 
            "\nESTADOS MARCADOS: " + marked_states
)

# %% [markdown]
# ### Simulação do algoritmo n_4_fixed_point_search_data_base_item no backend ibmqx4 do qiskit
# - Job id: 5ce755a3a2e59e00708cb6a4

# %%
python_module = "qiskit_cqd_n_4_fixed_point_search_data_base_backend"
algorithm = "Algoritmo de busca em base desordenada"
shots = 8 * 1024
work_qubits = 4
auxiliaries_qubits = 1
backend_name = "ibmqx4"
backend_type = "Dispositivo real"
marked_states = "0011, 0111, 1011, 1111"

# %%
executions_counts = [
    {'11101': 305, '00111': 64, '10101': 282, '00110': 378, '01100': 320, '10111': 53, '01001': 315, '10110': 379, '00000': 357, '10100': 307, '10010': 173, '11110': 370, '00101': 297, '00010': 143, '11010': 196, '00011': 174, '10001': 345, '11011': 179, '10011': 142, '11100': 312, '01110': 350, '10000': 358, '11001': 335, '01000': 349, '00100': 309, '11111': 64, '11000': 350, '01111': 51, '01010': 154, '01101': 286, '01011': 155, '00001': 340}
]

# %%
# Plot results with legend

legend = []

for index in range(len(executions_counts)):
    legend.append("Execução: " + str(index + 1))

# %%
# Plot graph
plot_histogram(
    data = executions_counts, 
    figsize = (15,5), 
    color = None, 
    number_to_keep = None, 
    sort = 'asc', 
    legend = legend, 
    bar_labels = False, 
    title = "HISTOGRAMA: " + algorithm + ", " + str(shots) + " shots, " + 
            str(work_qubits) + " qubits de trabalho e " + str(auxiliaries_qubits) + " qubit auxiliar" + 
            "\nEXECUTADO EM: " + backend_type + " " + backend_name + 
            "\nESTADOS MARCADOS: " + marked_states
)

# %% [markdown]
# ### Simulação do algoritmo n_4_fixed_point_search_data_base_item no backend ibmqx4 do qiskit
# - Job id: 5ce81f3d4aa56a0072184800

# %%
python_module = "qiskit_cqd_n_4_fixed_point_search_data_base_backend"
algorithm = "Algoritmo de busca em base desordenada"
shots = 8 * 1024
work_qubits = 4
auxiliaries_qubits = 1
backend_name = "ibmqx4"
backend_type = "Dispositivo real"
marked_states = "011, 111"

# %%
executions_counts = [
    {'0101': 837, '0110': 676, '0010': 199, '0011': 475, '0111': 148, '0100': 437, '1100': 380, '1000': 462, '1111': 153, '1010': 203, '0000': 476, '1001': 870, '1011': 427, '1110': 721, '0001': 960, '1101': 768}
]

# %%
# Plot results with legend

legend = []

for index in range(len(executions_counts)):
    legend.append("Execução: " + str(index + 1))

# %%
# Plot graph
plot_histogram(
    data = executions_counts, 
    figsize = (15,5), 
    color = None, 
    number_to_keep = None, 
    sort = 'asc', 
    legend = legend, 
    bar_labels = False, 
    title = "HISTOGRAMA: " + algorithm + ", " + str(shots) + " shots, " + 
            str(work_qubits) + " qubits de trabalho e " + str(auxiliaries_qubits) + " qubit auxiliar" + 
            "\nEXECUTADO EM: " + backend_type + " " + backend_name + 
            "\nESTADOS MARCADOS: " + marked_states
)
