# %% [markdown]
# ## Gráficos de simulações realizadas com QisKit no simulador online

# %% [markdown]
# ## imports

# %%
from qiskit.tools.visualization import plot_histogram

# %% [markdown]
# ### Simulação do algoritmo n_4_fixed_point_search_data_base_item no simulador online ibmq_qasm_simulator
# - python module: qiskit_cqd_n_4_fixed_point_search_data_base_backend
# - shots: 2 * 1024
# - work qubits: 3
# - auxiliaries qubits: 1
# - marked states: 011, 111
# - backend_name: ibmqx4
# - Job id: 5cd74ca86fa1a60072515abb
# - Job id: 5cd7500e56f5d2006d8fbd0f
# - Job id: 5cd7503750b66900725770a2
# - Job id: 5cd75040d91c93006ce4ec22

# %%
executions_counts = [
    {'0010': 26, '0011': 245, '0110': 250, '1000': 33, '1110': 286, '1101': 250, '1011': 229, '0100': 32, '1100': 29, '1010': 30, '0001': 205, '0101': 206, '1001': 203, '0000': 24},
    {'1100': 21, '0001': 214, '1000': 28, '0000': 32, '1110': 259, '0110': 267, '1101': 237, '1010': 23, '0100': 25, '0010': 34, '1001': 243, '0011': 229, '1011': 216, '0101': 220},
    {'0000': 27, '0010': 21, '1000': 32, '1100': 29, '0001': 230, '1110': 236, '1101': 235, '0101': 237, '0110': 250, '0100': 27, '1011': 251, '1010': 30, '1001': 232, '0011': 211},
    {'1000': 27, '0000': 28, '1100': 31, '1110': 257, '1011': 228, '0011': 219, '0110': 265, '1010': 31, '1101': 231, '0001': 232, '0010': 26, '0100': 31, '1001': 217, '0101': 225}
]

# %%
# Plot results with legend

legend = []

for index in range(len(executions_counts)):
    legend.append("Execução: " + str(index + 1))

# %%
# Plot graph
plot_histogram(
    data=executions_counts, 
    legend=legend, 
    figsize=(15,5), 
    bar_labels=False
)
